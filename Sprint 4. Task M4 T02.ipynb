# %% [markdown]
# ### Mustafa Habibi
#
# ### Sprint 4
#
# ##### Task M4 T02

# %% [markdown]
# - Exercise 2
# Do the tasks of preprocessing and adaptation of the Dataset we have in the GitHub repository  PRE-PROCESSING-DATA with the aim of preparing it and working on it as a dataframe to extract information from it.

# %% [markdown]
# important:
#
# The final result should be a dataframe with the variables movie name , year and genre.  It's also important to stick to just one genre for each movie!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
movies= pd.read_csv('movies.dat', sep='::', encoding='latin1', engine='python', header=None, names=['ID', 'Title', 'Genre'])
movies
# Out:
#         ID                               Title                         Genre
# 0        1                    Toy Story (1995)   Animation|Children's|Comedy
# 1        2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2        3             Grumpier Old Men (1995)                Comedy|Romance
# 3        4            Waiting to Exhale (1995)                  Comedy|Drama
# 4        5  Father of the Bride Part II (1995)                        Comedy
# ...    ...                                 ...                           ...
# 3878  3948             Meet the Parents (2000)                        Comedy
# 3879  3949          Requiem for a Dream (2000)                         Drama
# 3880  3950                    Tigerland (2000)                         Drama
# 3881  3951             Two Family House (2000)                         Drama
# 3882  3952               Contender, The (2000)                Drama|Thriller
#
# [3883 rows x 3 columns]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3883 entries, 0 to 3882
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      3883 non-null   int64
#  1   Title   3883 non-null   object
#  2   Genre   3883 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 91.1+ KB

# %%
movies.head(10)
# Out:
#    ID                               Title                         Genre
# 0   1                    Toy Story (1995)   Animation|Children's|Comedy
# 1   2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2   3             Grumpier Old Men (1995)                Comedy|Romance
# 3   4            Waiting to Exhale (1995)                  Comedy|Drama
# 4   5  Father of the Bride Part II (1995)                        Comedy
# 5   6                         Heat (1995)         Action|Crime|Thriller
# 6   7                      Sabrina (1995)                Comedy|Romance
# 7   8                 Tom and Huck (1995)          Adventure|Children's
# 8   9                 Sudden Death (1995)                        Action
# 9  10                    GoldenEye (1995)     Action|Adventure|Thriller

# %%
len(movies)
# Out:
# 3883

# %%
movies[['Title', 'Year']] = movies['Title'].str.extract(r'^(.*)\((\d{4})\)$') 
movies
# Out:
#         ID                         Title                         Genre  Year
# 0        1                    Toy Story    Animation|Children's|Comedy  1995
# 1        2                      Jumanji   Adventure|Children's|Fantasy  1995
# 2        3             Grumpier Old Men                 Comedy|Romance  1995
# 3        4            Waiting to Exhale                   Comedy|Drama  1995
# 4        5  Father of the Bride Part II                         Comedy  1995
# ...    ...                           ...                           ...   ...
# 3878  3948             Meet the Parents                         Comedy  2000
# 3879  3949          Requiem for a Dream                          Drama  2000
# 3880  3950                    Tigerland                          Drama  2000
# 3881  3951             Two Family House                          Drama  2000
# 3882  3952               Contender, The                 Drama|Thriller  2000
#
# [3883 rows x 4 columns]

# %%
movies['Genre'] = movies['Genre'].str.split('|') 
movies = movies.explode('Genre').reset_index() 
movies.head(20)
# Out:
#     index  ID                         Title       Genre  Year
# 0       0   1                    Toy Story    Animation  1995
# 1       0   1                    Toy Story   Children's  1995
# 2       0   1                    Toy Story       Comedy  1995
# 3       1   2                      Jumanji    Adventure  1995
# 4       1   2                      Jumanji   Children's  1995
# 5       1   2                      Jumanji      Fantasy  1995
# 6       2   3             Grumpier Old Men       Comedy  1995
# 7       2   3             Grumpier Old Men      Romance  1995
# 8       3   4            Waiting to Exhale       Comedy  1995
# 9       3   4            Waiting to Exhale        Drama  1995
# 10      4   5  Father of the Bride Part II       Comedy  1995
# 11      5   6                         Heat       Action  1995
# 12      5   6                         Heat        Crime  1995
# 13      5   6                         Heat     Thriller  1995
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6408 entries, 0 to 6407
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   6408 non-null   int64
#  1   ID      6408 non-null   int64
#  2   Title   6408 non-null   object
#  3   Genre   6408 non-null   object
#  4   Year    6408 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 250.4+ KB

# %%
movies= movies.astype({'Title': 'category', 'Genre': 'category', 'Year': 'int64'})
movies
# Out:
#       index    ID                 Title       Genre  Year
# 0         0     1            Toy Story    Animation  1995
# 1         0     1            Toy Story   Children's  1995
# 2         0     1            Toy Story       Comedy  1995
# 3         1     2              Jumanji    Adventure  1995
# 4         1     2              Jumanji   Children's  1995
# ...     ...   ...                   ...         ...   ...
# 6403   3879  3949  Requiem for a Dream        Drama  2000
# 6404   3880  3950            Tigerland        Drama  2000
# 6405   3881  3951     Two Family House        Drama  2000
# 6406   3882  3952       Contender, The        Drama  2000
# 6407   3882  3952       Contender, The     Thriller  2000
#
# [6408 rows x 5 columns]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6408 entries, 0 to 6407
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   6408 non-null   int64
#  1   ID      6408 non-null   int64
#  2   Title   6408 non-null   category
#  3   Genre   6408 non-null   category
#  4   Year    6408 non-null   int64
# dtypes: category(2), int64(3)
# memory usage: 328.8 KB

# %%
movies.nunique()
# Out:
# index    3883
# ID       3883
# Title    3841
# Genre      18
# Year       81
# dtype: int64

# %%
title= movies.Title.value_counts()

# %%
movies.drop(['ID', 'index'], axis= 1, inplace= True)

# %%
movies
# Out:
#                      Title       Genre  Year
# 0               Toy Story    Animation  1995
# 1               Toy Story   Children's  1995
# 2               Toy Story       Comedy  1995
# 3                 Jumanji    Adventure  1995
# 4                 Jumanji   Children's  1995
# ...                    ...         ...   ...
# 6403  Requiem for a Dream        Drama  2000
# 6404            Tigerland        Drama  2000
# 6405     Two Family House        Drama  2000
# 6406       Contender, The        Drama  2000
# 6407       Contender, The     Thriller  2000
#
# [6408 rows x 3 columns]

# %%
title
# Out:
# Jungle Book, The               7
# Mummy, The                     7
# King Kong                      6
# Mighty Joe Young               6
# That Darn Cat!                 6
#                               ..
# Fletch Lives                   1
# House on Haunted Hill          1
# House on Haunted Hill, The     1
# Concorde: Airport '79, The     1
# Kundun                         1
# Name: Title, Length: 3841, dtype: int64

# %%
genres= movies.Genre.value_counts()

# %%
genres
# Out:
# Drama          1603
# Comedy         1200
# Action          503
# Thriller        492
# Romance         471
# Horror          343
# Adventure       283
# Sci-Fi          276
# Children's      251
# Crime           211
# War             143
# Documentary     127
# Musical         114
# Mystery         106
# Animation       105
# Western          68
# Fantasy          68
# Film-Noir        44
# Name: Genre, dtype: int64

# %% [markdown]
# ## Exercise 3
# Show your creativity. What do you think is relevant to show about Dataset " movies.dat " from the previous exercise?
#
# Make one or two graphical representations and justify your choice.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
movies.plot.hist()
plt.show()

# %%
movies['Genre'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
x = movies.Genre
y = movies.Year
colors= 'darkblue'
plt.scatter(x, y, s=area, c=colors, alpha=0.4, edgecolors='black')

plt.title('movies by years')
plt.ylabel('movies')
plt.xlabel('Genre')
plt.show()

# %%
grouped_1= movies.groupby('Year')['Title'].count().reset_index(name= 'Total_movie_per_year').sort_values(by= 'Total_movie_per_year')

# %%
grouped_1
# Out:
#     Year  Total_movie_per_year
# 2   1921                     1
# 1   1920                     2
# 3   1922                     2
# 8   1928                     3
# 4   1923                     3
# ..   ...                   ...
# 79  1999                   431
# 77  1997                   540
# 76  1996                   541
# 75  1995                   547
# 78  1998                   572
#
# [81 rows x 2 columns]

# %%
grouped_1.plot.scatter(x= 'Year', y=  'Total_movie_per_year')
plt.show()

# %%
grouped_2 = movies.groupby(['Genre', 'Year']).size().reset_index(name='Total_Movies').sort_values(by='Year', ascending=True)

grouped_2.head(30)
# Out:
#             Genre  Year  Total_Movies
# 0          Action  1919             1
# 243    Children's  1919             0
# 1377      Western  1919             0
# 324        Comedy  1919             1
# 405         Crime  1919             0
# 486   Documentary  1919             0
# 1296          War  1919             0
# 162     Animation  1919             0
# 567         Drama  1919             2
# 729     Film-Noir  1919             0
# 1215     Thriller  1919             0
# 810        Horror  1919             0
# 891       Musical  1919             0
# 972       Mystery  1919             0
# 1053      Romance  1919             0
# 648       Fantasy  1919             0
# 81      Adventure  1919             1
# 1134       Sci-Fi  1919             0
# 568         Drama  1920             0
# 1378      Western  1920             0
# 973       Mystery  1920             0
# 82      Adventure  1920             0
# 1          Action  1920             0
# 1054      Romance  1920             0
# ...

# %% [markdown]
# In the chart below and table above, I showed the total number of movies by genre, and I think this is the  key chart to show how many movies were made in each genre.

# %%
plt.rcParams['figure.figsize'] = [18, 10]



sns.scatterplot(x='Year', y='Total_Movies', size='Total_Movies', hue='Genre',data=grouped_2, legend=True, sizes=(50, 1500))
plt.legend(bbox_to_anchor=(1, 1), fontsize= 14, loc='upper left')

plt.show()

# %%
x = grouped_2.Genre
y = grouped_2.Total_Movies
colors = 'Red'

plt.scatter(x, y, s=area, c=colors, alpha=0.9,edgecolors='black')

plt.title('Number of movies by Genre')
plt.ylabel('number of movies')
plt.xlabel('genre')
plt.show()

# %% [markdown]
# - I showed total movie by genre
# - I showed totla movie by  year. by the time passing, the number of movies were increased.
